# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
#구글 드라이브 마운트하기(이미 되어있다면 건너뛴다)
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
wal = pd.read_csv("/content/drive/MyDrive/Raw데이터(kaggle)/Walmart Sales Dataset of 45stores/walmart-sales-dataset-of-45stores.csv")

# %%
wal.head(5)
# Out:
#    store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           cpi  unemployment date_year date_month date_day  Week
# 0  211.096358         8.106      2010         02       05     5
# 1  211.242170         8.106      2010         02       12     6
# 2  211.289143         8.106      2010         02       19     7
# 3  211.319643         8.106      2010         02       26     8
# 4  211.350143         8.106      2010         03       05     9

# %%
wal.columns = wal.columns.str.lower()

# %%
wal['date_year'] = wal['date'].str[6:]

# %%
wal['date_month'] = wal['date'].str[3:5]

# %%
wal['date_day'] = wal['date'].str[0:2]

# %%
wal['date'] = wal['date_year'] +wal['date_month'] +wal['date_day']

# %%
wal['date'] = pd.to_datetime(wal['date'])

# %%
wal

# %%
wal.head(1)
# Out:
#    store      date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1  20100205     1643690.9             0        42.31       2.572
#
#           cpi  unemployment date_year date_month date_day
# 0  211.096358         8.106      2010         02       05

# %%
wal['Week'] = wal['date'].map(lambda x:x.isocalendar()[1])

# %%
pd.DataFrame(wal.groupby(['date_year','date_month'])['weekly_sales'].mean().round(3))
# Out:
#                       weekly_sales
# date_year date_month
# 2010      02           1057405.461
#           03           1010665.569
#           04           1028499.414
#           05           1037282.969
#           06           1068034.291
#           07           1033689.449
#           08           1042445.060
#           09            984821.646
#           10            965163.662
#           11           1126963.167
#           12           1283380.145
# 2011      01            909466.482
#           02           1035174.044
#           03            996424.713
#           04           1006784.493
#           05           1009156.434
#           06           1054296.584
#           07           1021828.439
#           08           1047774.068
#           09            981545.504
#           10           1018118.240
#           11           1167568.638
#           12           1280347.122
# 2012      01            938302.620
#           02           1067019.886
# ...

# %%
wal.groupby(['date_year','date_month'])['weekly_sales'].mean().round(3).reset_index()

# %%
plt.figure(figsize = (12,10))
a = wal.groupby(['date_year','date_month'])['weekly_sales'].mean().round(3).reset_index()
sns.barplot(data = a, x = 'date_month',y = 'weekly_sales',hue = 'date_year',palette = 'Set1',order = a.sort_values(by = 'weekly_sales').date_month)

# %%
wal['temperature'].mean()
# Out:
# 40.18024444444445

# %%
wal[wal['date_month'] == '10']['temperature'].mean()
# Out:
# 61.561709401709415

# %%
wal.groupby(['store'])['temperature'].mean()
# Out:
# store
# 1     68.306783
# 2     68.216364
# 3     71.434196
# 4     62.253357
# 5     69.410140
# 6     69.700000
# 7     39.720280
# 8     62.513986
# 9     67.775175
# 10    72.241189
# 11    72.480769
# 12    70.262797
# 13    53.697133
# 14    57.790979
# 15    51.833846
# 16    45.030070
# 17    46.387203
# 18    53.371259
# 19    52.295035
# 20    55.451399
# 21    68.847622
# 22    54.897133
# 23    48.805105
# 24    54.030000
# 25    52.138392
# 26    43.658252
# 27    57.311119
# 28    70.262797
# 29    54.897133
# 30    68.847622
# 31    68.847622
# 32    52.747552
# 33    76.728182
# 34    58.495874
# 35    57.311119
# 36    71.160350
# 37    71.160350
# 38    70.262797
# 39    70.597343
# 40    47.674545
# 41    48.410350
# 42    72.241189
# 43    68.877692
# 44    53.697133
# 45    57.790979
# Name: temperature, dtype: float64

# %%
plt.figure(figsize = (12,10))
a = wal.groupby(['store'])['weekly_sales'].mean().round(3).reset_index()
sns.barplot(data = a, x = 'store',y = 'weekly_sales',order = a.sort_values('weekly_sales',ascending = False).store)

# %%
sns.heatmap(wal.corr(),annot = True,fmt = '.2g')

# %%
wal.groupby(['store'])['weekly_sales'].mean().round(3).reset_index().sort_values(by = 'weekly_sales')

# %%
#wal[wal['store'] == 20].corr().plot.heatmap(annot = True)
a = sns.heatmap(wal[wal['store'] == 20].corr().corr(),annot = True,fmt = '.2g')
a

# %%
#wal[wal['store'] == 20].corr().plot.heatmap(annot = True)
a = sns.heatmap(wal[wal['store'] == 33].corr().corr(),annot = True,fmt = '.2g')
a

# %%
#wal[wal['store'] == 20].corr().plot.heatmap(annot = True)
a = sns.heatmap(wal[wal['store'] == 7].corr().corr(),annot = True,fmt = '.2g')
a

# %%
wal[wal['store'] == 20]['cpi'].mean()
# Out:
# 209.03813062867133

# %%
wal['cpi'].mean()
# Out:
# 171.57839384878014

# %%
wal.groupby(['cpi'])['fuel_price'].mean().round(3).reset_index()
# Out:
#              cpi  fuel_price
# 0     126.064000       2.957
# 1     126.076645       2.922
# 2     126.085452       2.948
# 3     126.089290       2.932
# 4     126.101935       2.936
# ...          ...         ...
# 2140  227.018417       3.594
# 2141  227.036936       3.506
# 2142  227.169392       3.601
# 2143  227.214288       3.594
# 2144  227.232807       3.506
#
# [2145 rows x 2 columns]

# %%
plt.figure(figsize = (12,10))
a = wal.groupby(['cpi'])['weekly_sales'].mean().round(3).reset_index()
sns.distplot(data = a, x = 'cpi',y = 'weekly_sales')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-8feb7437c2c1> in <module>
#       1 plt.figure(figsize = (12,10))
#       2 a = wal.groupby(['cpi'])['weekly_sales'].mean().round(3).reset_index()
# ----> 3 sns.distplot(data = a, x = 'cpi',y = 'weekly_sales')
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
wal.columns
# Out:
# Index(['store', 'date', 'weekly_sales', 'holiday_flag', 'temperature',
#        'fuel_price', 'cpi', 'unemployment', 'date_year', 'date_month',
#        'date_day', 'Week'],
#       dtype='object')

# %%
wal.groupby(['store'])['temperature'].mean()
# Out:
# store
# 1     68.306783
# 2     68.216364
# 3     71.434196
# 4     62.253357
# 5     69.410140
# 6     69.700000
# 7     39.720280
# 8     62.513986
# 9     67.775175
# 10    72.241189
# 11    72.480769
# 12    70.262797
# 13    53.697133
# 14    57.790979
# 15    51.833846
# 16    45.030070
# 17    46.387203
# 18    53.371259
# 19    52.295035
# 20    55.451399
# 21    68.847622
# 22    54.897133
# 23    48.805105
# 24    54.030000
# 25    52.138392
# 26    43.658252
# 27    57.311119
# 28    70.262797
# 29    54.897133
# 30    68.847622
# 31    68.847622
# 32    52.747552
# 33    76.728182
# 34    58.495874
# 35    57.311119
# 36    71.160350
# 37    71.160350
# 38    70.262797
# 39    70.597343
# 40    47.674545
# 41    48.410350
# 42    72.241189
# 43    68.877692
# 44    53.697133
# 45    57.790979
# Name: temperature, dtype: float64

# %%
wal.groupby(wal.groupby(['store'])['temperature'].mean())['fuel_price'].mean().round(3).reset_index().plot.line()

# %%
wal.columns
# Out:
# Index(['store', 'date', 'weekly_sales', 'holiday_flag', 'temperature',
#        'fuel_price', 'cpi', 'unemployment', 'date_year', 'date_month',
#        'date_day', 'Week'],
#       dtype='object')

# %%
wal.groupby(['holiday_flag'])['weekly_sales'].mean().round(3).plot.bar()

# %%
wal.groupby(['unemployment'])['weekly_sales'].mean().round(3).plot.line()
